# %% [markdown]
# # 안녕하세요^^
# ## AIVLE 미니프로젝트 '서울시 생활정보 기반 대중교통 수요 분석 ' 과정에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!
#
# ## 개인과제
# * 데이터 구조, 분포 확인, 전처리 : 1.1_버스정류장데이터 / 1.2 유동인구데이터 / 1.3_주민등록데이터 / 1.4_업종등록데이터
# * 데이터간 관계 가설 수립 및 검증 : 1.5_데이터 분석

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.
# ## "구별 업종 등록 데이터" 를 확인해 보도록 하겠습니다

# %%
# 필요 라이브러리부터 설치합니다.
# %pip install pandas seaborn

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 기본/추가 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * business_type.csv
#
# [데이터 소개]
# * 서울 시 구별 등록 업종 상위 10개 데이터
#     * 택시운송업
#     * 한식일반음식점업
#     * 용달 화물자동차 운송업
#     * 부동산 중개 및 대리업
#     * 두발미용업
#     * 커피전문점
#     * 남녀용 겉옷 및 셔츠 도매업
#     * 기타주점업
#     * 일반 교과 학원
#     * 한식 육류요리 전문점
#
# [변수 소개]
# * 다수 업종 상위 1~10

# %% [markdown]
# ---

# %% [markdown]
# # 1.데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)
# * csv : pd.read_csv("파일이름. csv")
# * txt : pd.read_csv("파일이름. csv", sep="구분자")
# * xlsx : pd.read_excel('파일이름.xlsx')
# * pickle : pd.read_pickle("파일이름.pkl") <br>
#  [참고] pickle은 파이썬의 모든 객체를 파일로 저장할 수 있는 방법으로 DataFrame,List,Dict 등 모든 객체 저장 가능(특히 sklearn라이브러리를 통해 모델을 학습시키고, 저장할 때 많이 사용)

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * 1.4 business_type.csv
#
# [데이터 소개]
# * 서울시 업종 등록 데이터

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * '1.4 business_type.csv'파일을 'seoul_business' 변수에 저장하고 그 데이터를 확인하세요.
#     * 데이터 파일 로딩시 참고 사항
#         * 구분자(sep)는 ',' 입니다
#         * UTF-8 인코더를 사용해 주세요

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
import pandas as pd
seoul_business = pd.read_csv('1.4 business_type.csv', sep=',', encoding='UTF-8')

# %%
# 데이터 프레임의 Shape을 확인합니다.
seoul_business.shape
# Out:
# (451, 22)

# %% [markdown]
# ---

# %% [markdown]
# # 2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [실습문제2] 기본 정보 확인하기
# * 'seoul_moving' 데이터의 정보를 확인해보세요.
# * 'describe', 'info', 'head' 등 전부 활용해 보겠습니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.describe()
# Out:
#         자치구    동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3 다수업종 상위10.4  \
# count   451  451       451         451         451         451         451
# unique   27  425       226         280         176         305         177
# top     송파구   소계        71          11          24         104          56
# freq     28   25         7           7          11           6           8
#
#        다수업종 상위10.5 다수업종 상위10.6 다수업종 상위10.7  ... 다수업종 상위10.10 다수업종 상위10.11  \
# count          451         451         451  ...          451          451
# unique         180         142         205  ...          131          239
# top             56          40          54  ...           13           16
# freq             9          11           9  ...           18            8
#
#        다수업종 상위10.12 다수업종 상위10.13 다수업종 상위10.14 다수업종 상위10.15 다수업종 상위10.16  \
# count           451          451          451          451          451
# unique           69          147          127          189          113
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   자치구           451 non-null    object
#  1   동             451 non-null    object
#  2   다수업종 상위10     451 non-null    object
#  3   다수업종 상위10.1   451 non-null    object
#  4   다수업종 상위10.2   451 non-null    object
#  5   다수업종 상위10.3   451 non-null    object
#  6   다수업종 상위10.4   451 non-null    object
#  7   다수업종 상위10.5   451 non-null    object
#  8   다수업종 상위10.6   451 non-null    object
#  9   다수업종 상위10.7   451 non-null    object
#  10  다수업종 상위10.8   451 non-null    object
#  11  다수업종 상위10.9   451 non-null    object
#  12  다수업종 상위10.10  451 non-null    object
#  13  다수업종 상위10.11  451 non-null    object
#  14  다수업종 상위10.12  451 non-null    object
#  15  다수업종 상위10.13  451 non-null    object
#  16  다수업종 상위10.14  451 non-null    object
#  17  다수업종 상위10.15  451 non-null    object
# ...

# %%
seoul_business.head()
# Out:
#    자치구    동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3   다수업종 상위10.4  \
# 0  자치구    동     택시운송업       택시운송업  한식 일반 음식점업  한식 일반 음식점업  용달 화물자동차 운송업
# 1  자치구    동      사업체수        종사자수        사업체수        종사자수          사업체수
# 2   합계   합계    47,176      76,701      29,225     100,183        28,494
# 3  종로구   소계       215         215       1,548       5,912           618
# 4  종로구  사직동         7           7         230         982            12
#
#     다수업종 상위10.5   다수업종 상위10.6   다수업종 상위10.7  ... 다수업종 상위10.10 다수업종 상위10.11  \
# 0  용달 화물자동차 운송업  부동산 중개 및 대리업  부동산 중개 및 대리업  ...        커피전문점        커피전문점
# 1          종사자수          사업체수          종사자수  ...         사업체수         종사자수
# 2        29,356        24,013        42,636  ...       16,255       57,322
# 3           646           549           889  ...          948        3,613
# 4            12            57            96  ...          124          525
#
#       다수업종 상위10.12     다수업종 상위10.13 다수업종 상위10.14 다수업종 상위10.15 다수업종 상위10.16  \
# ...

# %% [markdown]
# #### [실습문제3] 데이터 확인 및 처리
#
# * 데이터를 보았을때, 어느 데이터를 가져와야 할지 생각 해 봅시다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.drop('동', axis=1, inplace=True)

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.drop(2, axis=0, inplace=True)

# %%
seoul_business.loc[seoul_business['자치구']=='자치구'].value_counts()
# Out:
# 자치구  다수업종 상위10  다수업종 상위10.1  다수업종 상위10.2  다수업종 상위10.3  다수업종 상위10.4   다수업종 상위10.5   다수업종 상위10.6   다수업종 상위10.7   다수업종 상위10.8  다수업종 상위10.9  다수업종 상위10.10  다수업종 상위10.11  다수업종 상위10.12     다수업종 상위10.13     다수업종 상위10.14  다수업종 상위10.15  다수업종 상위10.16  다수업종 상위10.17  다수업종 상위10.18  다수업종 상위10.19
# 자치구  사업체수       종사자수         사업체수         종사자수         사업체수          종사자수          사업체수          종사자수          사업체수         종사자수         사업체수          종사자수          사업체수             종사자수             사업체수          종사자수          사업체수          종사자수          사업체수          종사자수            1
#      택시운송업      택시운송업        한식 일반 음식점업   한식 일반 음식점업   용달 화물자동차 운송업  용달 화물자동차 운송업  부동산 중개 및 대리업  부동산 중개 및 대리업  두발미용업        두발미용업        커피전문점         커피전문점         남녀용 겉옷 및 셔츠 도매업  남녀용 겉옷 및 셔츠 도매업  기타주점업         기타주점업         일반 교과 학원      일반 교과 학원      한식 육류요리 전문점   한식 육류요리 전문점     1
# dtype: int64

# %%
seoul_business.head()
# Out:
#    자치구 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3   다수업종 상위10.4  \
# 0  자치구     택시운송업       택시운송업  한식 일반 음식점업  한식 일반 음식점업  용달 화물자동차 운송업
# 1  자치구      사업체수        종사자수        사업체수        종사자수          사업체수
# 3  종로구       215         215       1,548       5,912           618
# 4  종로구         7           7         230         982            12
# 5  종로구         5           5          42         145             4
#
#     다수업종 상위10.5   다수업종 상위10.6   다수업종 상위10.7 다수업종 상위10.8  ... 다수업종 상위10.10  \
# 0  용달 화물자동차 운송업  부동산 중개 및 대리업  부동산 중개 및 대리업       두발미용업  ...        커피전문점
# 1          종사자수          사업체수          종사자수        사업체수  ...         사업체수
# 3           646           549           889         261  ...          948
# 4            12            57            96          28  ...          124
# 5             4             9            10           -  ...           66
#
#   다수업종 상위10.11     다수업종 상위10.12     다수업종 상위10.13 다수업종 상위10.14 다수업종 상위10.15  \
# ...

# %%
seoul_business.columns=['자치구', '택시운송업-사업체수', '택시운송업-종사자수', '한식 일반 음식점업-사업체수', '한식 일반 음식점업-종사자수', '용달 화물자동차 운송업-사업체수', '용달 화물자동차 운송업-종사자수', '부동산 중개 및 대리업-사업체수', '부동산 중개 및 대리업-종사자수', '두발미용업-사업체수', '두발미용업-종사자수', '커피전문점-사업체수', '커피전문점-종사자수', '남녀용 겉옷 및 셔츠 도매업-사업체수', '남녀용 겉옷 및 셔츠 도매업-종사자수', '기타주점업-사업체수', '기타주점업-종사자수', '일반 교과 학원-사업체수', '일반 교과 학원-종사자수', '한식 육류요리 전문점-사업체수', '한식 육류요리 전문점-종사자수']
seoul_business.head()
# Out:
#    자치구 택시운송업-사업체수 택시운송업-종사자수 한식 일반 음식점업-사업체수 한식 일반 음식점업-종사자수  \
# 0  자치구      택시운송업      택시운송업      한식 일반 음식점업      한식 일반 음식점업
# 1  자치구       사업체수       종사자수            사업체수            종사자수
# 3  종로구        215        215           1,548           5,912
# 4  종로구          7          7             230             982
# 5  종로구          5          5              42             145
#
#   용달 화물자동차 운송업-사업체수 용달 화물자동차 운송업-종사자수 부동산 중개 및 대리업-사업체수 부동산 중개 및 대리업-종사자수  \
# 0      용달 화물자동차 운송업      용달 화물자동차 운송업      부동산 중개 및 대리업      부동산 중개 및 대리업
# 1              사업체수              종사자수              사업체수              종사자수
# 3               618               646               549               889
# 4                12                12                57                96
# 5                 4                 4                 9                10
#
#   두발미용업-사업체수  ... 커피전문점-사업체수 커피전문점-종사자수 남녀용 겉옷 및 셔츠 도매업-사업체수  \
# 0      두발미용업  ...      커피전문점      커피전문점      남녀용 겉옷 및 셔츠 도매업
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.drop([0, 1], axis=0, inplace=True)

# %%
seoul_business.head()
# Out:
#    자치구 택시운송업-사업체수 택시운송업-종사자수 한식 일반 음식점업-사업체수 한식 일반 음식점업-종사자수  \
# 3  종로구        215        215           1,548           5,912
# 4  종로구          7          7             230             982
# 5  종로구          5          5              42             145
# 6  종로구         22         22              26             100
# 7  종로구         10         10              31             116
#
#   용달 화물자동차 운송업-사업체수 용달 화물자동차 운송업-종사자수 부동산 중개 및 대리업-사업체수 부동산 중개 및 대리업-종사자수  \
# 3               618               646               549               889
# 4                12                12                57                96
# 5                 4                 4                 9                10
# 6                 9                 9                17                26
# 7                11                11                33                52
#
#   두발미용업-사업체수  ... 커피전문점-사업체수 커피전문점-종사자수 남녀용 겉옷 및 셔츠 도매업-사업체수  \
# 3        261  ...        948      3,613                  400
# ...

# %%
seoul_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 448 entries, 3 to 450
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   자치구                   448 non-null    object
#  1   택시운송업-사업체수            448 non-null    object
#  2   택시운송업-종사자수            448 non-null    object
#  3   한식 일반 음식점업-사업체수       448 non-null    object
#  4   한식 일반 음식점업-종사자수       448 non-null    object
#  5   용달 화물자동차 운송업-사업체수     448 non-null    object
#  6   용달 화물자동차 운송업-종사자수     448 non-null    object
#  7   부동산 중개 및 대리업-사업체수     448 non-null    object
#  8   부동산 중개 및 대리업-종사자수     448 non-null    object
#  9   두발미용업-사업체수            448 non-null    object
#  10  두발미용업-종사자수            448 non-null    object
#  11  커피전문점-사업체수            448 non-null    object
#  12  커피전문점-종사자수            448 non-null    object
#  13  남녀용 겉옷 및 셔츠 도매업-사업체수  448 non-null    object
#  14  남녀용 겉옷 및 셔츠 도매업-종사자수  448 non-null    object
# ...

# %%
temp_li = [i for i in seoul_business.columns]
del temp_li[0]
print(temp_li)
# Out:
# ['택시운송업-사업체수', '택시운송업-종사자수', '한식 일반 음식점업-사업체수', '한식 일반 음식점업-종사자수', '용달 화물자동차 운송업-사업체수', '용달 화물자동차 운송업-종사자수', '부동산 중개 및 대리업-사업체수', '부동산 중개 및 대리업-종사자수', '두발미용업-사업체수', '두발미용업-종사자수', '커피전문점-사업체수', '커피전문점-종사자수', '남녀용 겉옷 및 셔츠 도매업-사업체수', '남녀용 겉옷 및 셔츠 도매업-종사자수', '기타주점업-사업체수', '기타주점업-종사자수', '일반 교과 학원-사업체수', '일반 교과 학원-종사자수', '한식 육류요리 전문점-사업체수', '한식 육류요리 전문점-종사자수']

# %%
for i in seoul_business.columns:
    seoul_business[i] = seoul_business[i].str.replace('-', '0')
    seoul_business[i] = seoul_business[i].str.replace(',', '')
    
seoul_business.head()
# Out:
#    자치구 택시운송업-사업체수 택시운송업-종사자수 한식 일반 음식점업-사업체수 한식 일반 음식점업-종사자수  \
# 3  종로구        215        215            1548            5912
# 4  종로구          7          7             230             982
# 5  종로구          5          5              42             145
# 6  종로구         22         22              26             100
# 7  종로구         10         10              31             116
#
#   용달 화물자동차 운송업-사업체수 용달 화물자동차 운송업-종사자수 부동산 중개 및 대리업-사업체수 부동산 중개 및 대리업-종사자수  \
# 3               618               646               549               889
# 4                12                12                57                96
# 5                 4                 4                 9                10
# 6                 9                 9                17                26
# 7                11                11                33                52
#
#   두발미용업-사업체수  ... 커피전문점-사업체수 커피전문점-종사자수 남녀용 겉옷 및 셔츠 도매업-사업체수  \
# 3        261  ...        948       3613                  400
# ...

# %%
for i in temp_li:
    seoul_business = seoul_business.astype({i:'int'})

# %%
seoul_business.head()
# Out:
#    자치구  택시운송업-사업체수  택시운송업-종사자수  한식 일반 음식점업-사업체수  한식 일반 음식점업-종사자수  \
# 3  종로구         215         215             1548             5912
# 4  종로구           7           7              230              982
# 5  종로구           5           5               42              145
# 6  종로구          22          22               26              100
# 7  종로구          10          10               31              116
#
#    용달 화물자동차 운송업-사업체수  용달 화물자동차 운송업-종사자수  부동산 중개 및 대리업-사업체수  부동산 중개 및 대리업-종사자수  \
# 3                618                646                549                889
# 4                 12                 12                 57                 96
# 5                  4                  4                  9                 10
# 6                  9                  9                 17                 26
# 7                 11                 11                 33                 52
#
#    두발미용업-사업체수  ...  커피전문점-사업체수  커피전문점-종사자수  남녀용 겉옷 및 셔츠 도매업-사업체수  \
# ...

# %%
seoul_business = seoul_business.groupby('자치구', as_index=False).sum()

# %%
seoul_business
# Out:
#      자치구  택시운송업-사업체수  택시운송업-종사자수  한식 일반 음식점업-사업체수  한식 일반 음식점업-종사자수  \
# 0    강남구        3592        5034             4830            22972
# 1    강동구        6590        9960             2202             6776
# 2    강북구        3426        5178             1930             5326
# 3    강서구        7470       13844             2650             9168
# 4    관악구        2572        4054             2452             7378
# 5    광진구        2238        3488             1926             5722
# 6    구로구        5514        7634             2096             6430
# 7    금천구        2200        5196             1734             5238
# 8    노원구        8228       12148             1732             5300
# 9    도봉구        5986       11566             1344             4018
# 10  동대문구        3092        4186             2472             7132
# 11   동작구        2066        2230             1530             4644
# 12   마포구        2330        3676             2822             9410
# ...

# %%
seoul_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   자치구                   25 non-null     object
#  1   택시운송업-사업체수            25 non-null     int32
#  2   택시운송업-종사자수            25 non-null     int32
#  3   한식 일반 음식점업-사업체수       25 non-null     int32
#  4   한식 일반 음식점업-종사자수       25 non-null     int32
#  5   용달 화물자동차 운송업-사업체수     25 non-null     int32
#  6   용달 화물자동차 운송업-종사자수     25 non-null     int32
#  7   부동산 중개 및 대리업-사업체수     25 non-null     int32
#  8   부동산 중개 및 대리업-종사자수     25 non-null     int32
#  9   두발미용업-사업체수            25 non-null     int32
#  10  두발미용업-종사자수            25 non-null     int32
#  11  커피전문점-사업체수            25 non-null     int32
#  12  커피전문점-종사자수            25 non-null     int32
#  13  남녀용 겉옷 및 셔츠 도매업-사업체수  25 non-null     int32
#  14  남녀용 겉옷 및 셔츠 도매업-종사자수  25 non-null     int32
# ...

# %%
# 해당 데이터프레임을 'df_seoul_business.csv' 파일로 저장하세요.
seoul_business.to_csv('df_seoul_business.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# # 3.데이터 분석하기
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 데이터들의 패턴 탐색
#   * 변수들간의 관계 파악

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화 한글폰트 설정
# 맑은 고딕

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# scipy
import scipy.stats as spst

# %% [markdown]
# #### [실습문제4] 데이터 분포 알아보기
# * 다양한 변수를 기준으로 그래프를 그려보고 인사이트를 도출해보세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
plt.figure(figsize=(20, 8))

plt.subplot(2, 1, 1)
plt.plot('자치구', '인구', data=seoul_people, marker='o')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot('자치구', '세대', data=seoul_people, marker='o')
plt.legend()

plt.show()

# %% [markdown]
# ---
